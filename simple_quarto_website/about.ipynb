# %% [markdown]
# ---
# title: "About"
# ---
#
# About this site

# %% [markdown]
# # Header 1
#
# ## Header 1.1
#
# ### Header 1.1.1

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10, 0.01)
y = np.sin(x)
plt.plot(x, y)
plt.show()
